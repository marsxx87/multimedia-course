# %% [markdown]
# #專案下載

# %%
# !git clone https://github.com/quancore/social-lstm
# Out:
# Cloning into 'social-lstm'...
# remote: Enumerating objects: 247, done.
# remote: Total 247 (delta 0), reused 0 (delta 0), pack-reused 247
# Receiving objects: 100% (247/247), 5.43 MiB | 18.29 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# %cd social-lstm/
# Out:
# /content/social-lstm

# %% [markdown]
# #訓練模型

# %%
# !python train.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 700/109020 (epoch 0), train_loss = -1.246, time/batch = 2.288
# 701/109020 (epoch 0), train_loss = -1.264, time/batch = 2.205
# 702/109020 (epoch 0), train_loss = -1.205, time/batch = 2.167
# 703/109020 (epoch 0), train_loss = -1.254, time/batch = 2.140
# 704/109020 (epoch 0), train_loss = -1.287, time/batch = 2.155
# 705/109020 (epoch 0), train_loss = -1.428, time/batch = 2.099
# 706/109020 (epoch 0), train_loss = -1.553, time/batch = 1.962
# 707/109020 (epoch 0), train_loss = -1.628, time/batch = 1.816
# 708/109020 (epoch 0), train_loss = -1.780, time/batch = 1.655
# 709/109020 (epoch 0), train_loss = -1.854, time/batch = 1.470
# 710/109020 (epoch 0), train_loss = -1.770, time/batch = 1.438
# 711/109020 (epoch 0), train_loss = -1.888, time/batch = 1.417
# 712/109020 (epoch 0), train_loss = -1.702, time/batch = 1.316
# 713/109020 (epoch 0), train_loss = -1.557, time/batch = 1.264
# 714/109020 (epoch 0), train_loss = -1.874, time/batch = 1.285
# ...

# %% [markdown]
# #模型預測

# %%
# !python test.py

# %% [markdown]
# #模型驗證

# %%
# !python validation.py

# %% [markdown]
# #模型可視化結果

# %%
# !python visualize.py
